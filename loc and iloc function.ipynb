# %%
import pandas as pd
import numpy as np

# %%
ufo = pd.read_csv('http://bit.ly/uforeports')

# %%
ufo.head(3)
# Out:
#           City Colors Reported Shape Reported State             Time
# 0       Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1  Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2      Holyoke             NaN           OVAL    CO  2/15/1931 14:00

# %% [markdown]
# # loc funtion - inclusive both the number, first and second

# %%
ufo.loc[0,:]
# Out:
# City                       Ithaca
# Colors Reported               NaN
# Shape Reported           TRIANGLE
# State                          NY
# Time               6/1/1930 22:00
# Name: 0, dtype: object

# %%
ufo.loc[[0,1,2],:]
# Out:
#           City Colors Reported Shape Reported State             Time
# 0       Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1  Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2      Holyoke             NaN           OVAL    CO  2/15/1931 14:00

# %%
ufo.loc[0:2,:]
# Out:
#           City Colors Reported Shape Reported State             Time
# 0       Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1  Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2      Holyoke             NaN           OVAL    CO  2/15/1931 14:00

# %%
ufo.loc[0:2]  # dont do this ever
# Out:
#           City Colors Reported Shape Reported State             Time
# 0       Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1  Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2      Holyoke             NaN           OVAL    CO  2/15/1931 14:00

# %%
ufo.loc[:,['City','State']]   # ufo.loc[R,C]
# Out:
#                        City State
# 0                    Ithaca    NY
# 1               Willingboro    NJ
# 2                   Holyoke    CO
# 3                   Abilene    KS
# 4      New York Worlds Fair    NY
# ...                     ...   ...
# 18236            Grant Park    IL
# 18237           Spirit Lake    IA
# 18238           Eagle River    WI
# 18239           Eagle River    WI
# 18240                  Ybor    FL
#
# [18241 rows x 2 columns]

# %%
ufo.loc[0:2,'City':'State']#use this method
# Out:
#           City Colors Reported Shape Reported State
# 0       Ithaca             NaN       TRIANGLE    NY
# 1  Willingboro             NaN          OTHER    NJ
# 2      Holyoke             NaN           OVAL    CO

# %%
ufo.head(3).drop('Time', axis=1) # dont use this method
# Out:
#           City Colors Reported Shape Reported State
# 0       Ithaca             NaN       TRIANGLE    NY
# 1  Willingboro             NaN          OTHER    NJ
# 2      Holyoke             NaN           OVAL    CO

# %%
ufo[ufo.City == 'Oakland'] # If I want to select all the row containing city as Oakland
# Out:
#           City Colors Reported Shape Reported State              Time
# 1694   Oakland             NaN          CIGAR    CA   7/21/1968 14:00
# 2144   Oakland             NaN           DISK    CA    8/19/1971 0:00
# 4686   Oakland             NaN          LIGHT    MD     6/1/1982 0:00
# 7293   Oakland             NaN          LIGHT    CA   3/28/1994 17:00
# 8488   Oakland             NaN            NaN    CA   8/10/1995 21:45
# 8768   Oakland             NaN            NaN    CA  10/10/1995 22:40
# 10816  Oakland             NaN          LIGHT    OR   10/1/1997 21:30
# 10948  Oakland             NaN           DISK    CA  11/14/1997 19:55
# 11045  Oakland             NaN       TRIANGLE    CA   12/10/1997 1:30
# 12322  Oakland             NaN       FIREBALL    CA   10/9/1998 19:40
# 12941  Oakland             NaN       CYLINDER    CA   1/23/1999 21:30
# 16803  Oakland             NaN       TRIANGLE    MD    7/4/2000 23:00
# ...

# %%
ufo.loc[ufo.City =='Oakland',:] #if I want to select all rows containing city as Oakland using loc function
# Out:
#           City Colors Reported Shape Reported State              Time
# 1694   Oakland             NaN          CIGAR    CA   7/21/1968 14:00
# 2144   Oakland             NaN           DISK    CA    8/19/1971 0:00
# 4686   Oakland             NaN          LIGHT    MD     6/1/1982 0:00
# 7293   Oakland             NaN          LIGHT    CA   3/28/1994 17:00
# 8488   Oakland             NaN            NaN    CA   8/10/1995 21:45
# 8768   Oakland             NaN            NaN    CA  10/10/1995 22:40
# 10816  Oakland             NaN          LIGHT    OR   10/1/1997 21:30
# 10948  Oakland             NaN           DISK    CA  11/14/1997 19:55
# 11045  Oakland             NaN       TRIANGLE    CA   12/10/1997 1:30
# 12322  Oakland             NaN       FIREBALL    CA   10/9/1998 19:40
# 12941  Oakland             NaN       CYLINDER    CA   1/23/1999 21:30
# 16803  Oakland             NaN       TRIANGLE    MD    7/4/2000 23:00
# ...

# %% [markdown]
# # iloc - function - exclusive of the 2nd number and inclusive of the first number
#
# iloc - here i stands for the integer

# %%
ufo.iloc[:,0:4]         #ufo.iloc[R,C] - here 0:4 is the integer range
# Out:
#                        City Colors Reported Shape Reported State
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
# [18241 rows x 4 columns]

# %%
list(range(0,4))
# Out:
# [0, 1, 2, 3]

# %%
ufo.iloc[0:10,:5]
# Out:
#                    City Colors Reported Shape Reported State              Time
# 0                Ithaca             NaN       TRIANGLE    NY    6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ   6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO   2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS    6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY   4/18/1933 19:00
# 5           Valley City             NaN           DISK    ND   9/15/1934 15:30
# 6           Crater Lake             NaN         CIRCLE    CA    6/15/1935 0:00
# 7                  Alma             NaN           DISK    MI    7/15/1936 0:00
# 8               Eklutna             NaN          CIGAR    AK  10/15/1936 17:00
# 9               Hubbard             NaN       CYLINDER    OR    6/15/1937 0:00

# %%
ufo.isnull().columns
# Out:
# Index(['City', 'Colors Reported', 'Shape Reported', 'State', 'Time'], dtype='object')

# %%
ufo.columns
# Out:
# Index(['City', 'Colors Reported', 'Shape Reported', 'State', 'Time'], dtype='object')

# %%
ufo.loc[ufo['Shape Reported'].isnull(),:]
# Out:
#                  City Colors Reported Shape Reported State              Time
# 16        Los Angeles             NaN            NaN    CA    2/25/1942 0:00
# 17          Hapeville             NaN            NaN    GA    6/1/1942 22:30
# 21                NaN             NaN            NaN    LA    8/15/1943 0:00
# 53             Minden             NaN            NaN    LA     6/1/1947 0:00
# 56           Oroville             NaN            NaN    CA    6/1/1947 18:00
# ...               ...             ...            ...   ...               ...
# 18206      Cerrilillo             NaN            NaN    NM  12/28/2000 11:00
# 18223      Greenville             NaN            NaN    SC  12/29/2000 22:00
# 18232            Lodi             NaN            NaN    WI  12/31/2000 20:30
# 18235  Fountain Hills             NaN            NaN    AZ  12/31/2000 23:00
# 18238     Eagle River             NaN            NaN    WI  12/31/2000 23:45
#
# [2644 rows x 5 columns]

# %%
ufo.dropna(axis=1)
# Out:
#       State              Time
# 0        NY    6/1/1930 22:00
# 1        NJ   6/30/1930 20:00
# 2        CO   2/15/1931 14:00
# 3        KS    6/1/1931 13:00
# 4        NY   4/18/1933 19:00
# ...     ...               ...
# 18236    IL  12/31/2000 23:00
# 18237    IA  12/31/2000 23:00
# 18238    WI  12/31/2000 23:45
# 18239    WI  12/31/2000 23:45
# 18240    FL  12/31/2000 23:59
#
# [18241 rows x 2 columns]

# %%
a = ufo['State'].value_counts(ascending=True)
